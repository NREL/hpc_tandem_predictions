# %% [markdown]
# ## This notebook is used to optimize the runtime prediction model.
# It should be noted that this process is computationally expensive and will take a long time to run for a significant number of split times. Because of this, the example shown here is only for two split times. However, because the results of each split time are independent, this code can be parallelized. How we achieved this is by using the Python scripts in the python_scripts directory, submitting each split time as a different job to the HPC system (Eagle), and combining the results in post-processing. Future updates to this repo will include parallelized code so this inherent parallelism can be taken advantage of directly within this notebook.

# %% [markdown]
# # Import necessary packages

# %%
import pandas as pd
import datetime
import os

from eagle_jobs.model_optimization import optimize_training_window
from eagle_jobs.model_optimization import optimize_testing_window
from eagle_jobs.model_optimization import optimize_numerical_features
from eagle_jobs.model_optimization import optimize_categorical_features
# Out:
# 2023-05-09 22:38:55.241293: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Import Eagle data

# %%
filepath = os.path.join('../data/', 'eagle_data.parquet')
eagle_df = pd.read_parquet(filepath)

# %% [markdown]
# # Get split times

# %%
start_time = pd.Timestamp('2022-01-01')
end_time = pd.Timestamp('2022-01-07')
split_times = pd.date_range(start_time, end_time, freq='6D')

# %% [markdown]
# # Optimize Training Window

# %%
model_type='XGBoost' # Options are 'XGBoost', 'NN', and 'TFIDF'
r2_train, rmse_train = optimize_training_window(eagle_df, split_times, model_type)

optimize_training_window_df = pd.DataFrame({'training_window': list(r2_train.keys()), \
                                            'r2': list(r2_train.values()), 'rmse': list(rmse_train.values())})

now = datetime.datetime.now().strftime('%Y%m%d_%H%M')
filename = 'optimize_training_window_df_'+now+'.pkl'
filepath = os.path.join('..','results',filename)
optimize_training_window_df.to_pickle(filepath)

optimal_training_window = min(rmse_train, key=lambda k: sum(rmse_train[k]) / len(rmse_train[k]))
print('Optimal Training Window:', optimal_training_window)
# Out:
# Split time: 2022-01-01 00:00:00, training window: 1, r2: -0.492, rmse: 45352
# Split time: 2022-01-01 00:00:00, training window: 5, r2: -0.272, rmse: 41881
# Split time: 2022-01-01 00:00:00, training window: 10, r2: -0.132, rmse: 39507
# Split time: 2022-01-01 00:00:00, training window: 15, r2: -0.016, rmse: 37426
# Split time: 2022-01-01 00:00:00, training window: 20, r2: -0.141, rmse: 39663
# Split time: 2022-01-01 00:00:00, training window: 25, r2: -0.216, rmse: 40948
# Split time: 2022-01-01 00:00:00, training window: 30, r2: -0.010, rmse: 37317
# Split time: 2022-01-01 00:00:00, training window: 35, r2: 0.096, rmse: 35297
# Split time: 2022-01-01 00:00:00, training window: 40, r2: 0.100, rmse: 35232
# Split time: 2022-01-01 00:00:00, training window: 45, r2: 0.140, rmse: 34437
# Split time: 2022-01-01 00:00:00, training window: 50, r2: 0.095, rmse: 35311
# Split time: 2022-01-01 00:00:00, training window: 55, r2: 0.141, rmse: 34408
# Split time: 2022-01-01 00:00:00, training window: 60, r2: 0.157, rmse: 34079
# Split time: 2022-01-01 00:00:00, training window: 65, r2: 0.023, rmse: 36703
# Split time: 2022-01-01 00:00:00, training window: 70, r2: -0.001, rmse: 37139
# Split time: 2022-01-01 00:00:00, training window: 75, r2: -0.206, rmse: 40777
# Split time: 2022-01-01 00:00:00, training window: 80, r2: -0.051, rmse: 38071
# Split time: 2022-01-07 00:00:00, training window: 85, r2: 0.029, rmse: 37667
# Split time: 2022-01-07 00:00:00, training window: 90, r2: -0.056, rmse: 39276
# Split time: 2022-01-07 00:00:00, training window: 95, r2: -0.019, rmse: 38575
# Split time: 2022-01-07 00:00:00, training window: 100, r2: -0.017, rmse: 38543
# Split time: 2022-01-07 00:00:00, training window: 105, r2: -0.016, rmse: 38516
# Split time: 2022-01-07 00:00:00, training window: 110, r2: -0.047, rmse: 39103
# Split time: 2022-01-07 00:00:00, training window: 115, r2: -0.062, rmse: 39394
# Split time: 2022-01-07 00:00:00, training window: 120, r2: -0.078, rmse: 39682
# Split time: 2022-01-07 00:00:00, training window: 125, r2: -0.108, rmse: 40233
# Split time: 2022-01-07 00:00:00, training window: 130, r2: -0.058, rmse: 39303
# Split time: 2022-01-07 00:00:00, training window: 135, r2: -0.075, rmse: 39629
# Split time: 2022-01-07 00:00:00, training window: 140, r2: -0.097, rmse: 40035
# Split time: 2022-01-07 00:00:00, training window: 145, r2: -0.085, rmse: 39810
# Split time: 2022-01-07 00:00:00, training window: 150, r2: -0.095, rmse: 39991
# Split time: 2022-01-07 00:00:00, training window: 155, r2: -0.074, rmse: 39603
# Split time: 2022-01-07 00:00:00, training window: 160, r2: -0.075, rmse: 39627
# Split time: 2022-01-07 00:00:00, training window: 165, r2: -0.101, rmse: 40109
# Split time: 2022-01-07 00:00:00, training window: 170, r2: -0.146, rmse: 40909
# Split time: 2022-01-07 00:00:00, training window: 175, r2: -0.148, rmse: 40941
# Split time: 2022-01-07 00:00:00, training window: 180, r2: -0.156, rmse: 41086
# Optimal Training Window: 60

# %% [markdown]
# # Optimize Testing Window

# %%
r2_test, rmse_test = optimize_testing_window(eagle_df, split_times, optimal_training_window)

optimize_testing_window_df = pd.DataFrame({'testing_window': list(r2_test.keys()), 'r2': list(r2_test.values()), 'rmse': list(rmse_test.values())})

now = datetime.datetime.now().strftime('%Y%m%d_%H%M')
filename = 'optimize_testing_window_df_'+now+'.pkl'
filepath = os.path.join('..','results',filename)
optimize_testing_window_df.to_pickle(filepath)

optimal_testing_window = min(rmse_test, key=lambda k: sum(rmse_test[k]) / len(rmse_test[k]))
print('Optimal Testing Window:', optimal_testing_window)
# Out:
# Split time: 2022-01-01 00:00:00, testing window: 1, r2: -0.252, rmse: 61426
# Split time: 2022-01-01 00:00:00, testing window: 2, r2: -0.174, rmse: 33207
# Split time: 2022-01-01 00:00:00, testing window: 3, r2: -1.197, rmse: 51599
# Split time: 2022-01-01 00:00:00, testing window: 4, r2: 0.649, rmse: 31270
# Split time: 2022-01-01 00:00:00, testing window: 5, r2: 0.369, rmse: 19353
# Split time: 2022-01-01 00:00:00, testing window: 6, r2: 0.294, rmse: 33422
# Split time: 2022-01-01 00:00:00, testing window: 7, r2: -0.131, rmse: 23218
# Split time: 2022-01-01 00:00:00, testing window: 8, r2: -0.016, rmse: 22537
# Split time: 2022-01-01 00:00:00, testing window: 9, r2: -0.093, rmse: 16686
# ### Optimize Numerical Features
# * Assume we should use Wallclock Req as a minimum feature set.
# * Use optimal number of training & testing days
# * In addition to wallclock, run all combinations of Nodes, Processors, GPUs, and Mem (2^4 = 16 combinations)

# %%
r2_num_feat, rmse_num_feat = optimize_numerical_features(eagle_df, split_times, optimal_training_window, optimal_testing_window)

optimize_numerical_features_df = pd.DataFrame({'features': list(r2_num_feat.keys()), 'r2': list(r2_num_feat.values()), 'rmse': list(rmse_num_feat.values())})

now = datetime.datetime.now().strftime('%Y%m%d_%H%M')
filename = 'optimize_numerical_features_df_'+now+'.pkl'
filepath = os.path.join('..','results',filename)
optimize_numerical_features_df.to_pickle(filepath)

optimal_numerical_features = min(rmse_num_feat, key=lambda k: sum(rmse_num_feat[k]) / len(rmse_num_feat[k]))
print('Optimal Numerical Features:', optimal_numerical_features)
# Out:
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req',), r2: -0.285, rmse: 38427
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req'), r2: -0.184, rmse: 36889
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req'), r2: 0.288, rmse: 28596
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'gpus_req'), r2: -0.296, rmse: 38587
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'mem_req'), r2: 0.087, rmse: 32379
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req'), r2: 0.229, rmse: 29763
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'gpus_req'), r2: -0.190, rmse: 36978
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'mem_req'), r2: 0.211, rmse: 30113
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req'), r2: 0.363, rmse: 27060
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'mem_req'), r2: 0.257, rmse: 29216
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'gpus_req', 'mem_req'), r2: 0.074, rmse: 32623
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'gpus_req'), r2: 0.335, rmse: 27643
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'mem_req'), r2: 0.354, rmse: 27234
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'gpus_req', 'mem_req'), r2: 0.197, rmse: 30369
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'mem_req'), r2: 0.374, rmse: 26818
# Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'gpus_req', 'mem_req'), r2: 0.370, rmse: 26899
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req',), r2: 0.137, rmse: 33963
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req'), r2: 0.173, rmse: 33244
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req'), r2: 0.102, rmse: 34657
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'gpus_req'), r2: 0.151, rmse: 33686
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'mem_req'), r2: 0.062, rmse: 35405
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req'), r2: 0.125, rmse: 34213
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'gpus_req'), r2: 0.186, rmse: 32999
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'mem_req'), r2: -0.111, rmse: 38534
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req'), r2: 0.147, rmse: 33762
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'mem_req'), r2: -0.179, rmse: 39698
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'gpus_req', 'mem_req'), r2: -0.151, rmse: 39229
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'gpus_req'), r2: 0.131, rmse: 34078
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'mem_req'), r2: -0.319, rmse: 41988
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'gpus_req', 'mem_req'), r2: -0.213, rmse: 40270
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'mem_req'), r2: -0.241, rmse: 40733
# Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'nodes_req', 'processors_req', 'gpus_req', 'mem_req'), r2: -0.157, rmse: 39325
# Optimal Numerical Features: ('wallclock_req', 'processors_req', 'gpus_req')

# %% [markdown]
# ### Optimize Categorical Features + Encoding
# * With optimal train days, test days, and numerical feature set, test the following encodings:
#     * Label encoding: Label all categorical features
#     * Target encoding: Get target encoding for all categorical features
#     * Onehot (top n) Encoding: One-hot encode top n instances of categorical features (group the rest as 'other')
#         * Top 20 users
#         * Top 6 partitions
#         * Top 15 accounts
#         * Top 20 name
#         * Top 20 work_dir
# * Run all combinations of User, Account, Partition, QOS, Name, and Work Dir (2^6 = 64 combinations)

# %%
optimal_features = dict()
for encoding in ['label','onehot','target']:
    r2_cat_feat, rmse_cat_feat = optimize_categorical_features(eagle_df, split_times, optimal_training_window, optimal_testing_window, optimal_numerical_features, encoding)

    optimize_categorical_features_df = pd.DataFrame({'features': list(r2_cat_feat.keys()), 'r2': list(r2_cat_feat.values()), 'rmse': list(rmse_cat_feat.values())})

    now = datetime.datetime.now().strftime('%Y%m%d_%H%M')
    filename = 'optimize_categorical_features_df_'+encoding+'_'+now+'.pkl'
    filepath = os.path.join('..','results',filename)
    optimize_categorical_features_df.to_pickle(filepath)

    optimal_features[encoding] = min(rmse_cat_feat, key=lambda k: sum(rmse_cat_feat[k]) / len(rmse_cat_feat[k]))
    print(f'Optimal Features with {encoding} Encoding:', optimal_features[encoding])
# Out:
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req'), r2: 0.363, rmse: 27060
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user'), r2: -0.001, rmse: 33918
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account'), r2: -3.537, rmse: 72193
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition'), r2: 0.321, rmse: 27931
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos'), r2: -0.160, rmse: 36506
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'work_dir'), r2: 0.336, rmse: 27613
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'name'), r2: 0.320, rmse: 27952
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account'), r2: -1.453, rmse: 53082
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition'), r2: -0.047, rmse: 34685
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos'), r2: -0.158, rmse: 36468
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'work_dir'), r2: 0.350, rmse: 27336
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'name'), r2: 0.212, rmse: 30083
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition'), r2: -3.752, rmse: 73886
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos'), r2: -3.129, rmse: 68874
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'work_dir'), r2: 0.326, rmse: 27831
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'name'), r2: -0.391, rmse: 39981
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos'), r2: -0.163, rmse: 36555
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'work_dir'), r2: 0.358, rmse: 27158
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'name'), r2: 0.393, rmse: 26403
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'work_dir'), r2: 0.363, rmse: 27052
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'name'), r2: 0.367, rmse: 26972
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'work_dir', 'name'), r2: 0.406, rmse: 26126
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition'), r2: -1.786, rmse: 56572
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos'), r2: -1.896, rmse: 57683
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir'), r2: 0.433, rmse: 25526
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'name'), r2: -0.426, rmse: 40480
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos'), r2: -0.085, rmse: 35309
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'work_dir'), r2: 0.412, rmse: 25991
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'name'), r2: 0.371, rmse: 26881
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos', 'work_dir'), r2: 0.480, rmse: 24435
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos', 'name'), r2: 0.209, rmse: 30141
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'work_dir', 'name'), r2: 0.234, rmse: 29661
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'qos'), r2: -2.759, rmse: 65713
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'work_dir'), r2: 0.429, rmse: 25622
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'name'), r2: 0.036, rmse: 33285
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos', 'work_dir'), r2: 0.411, rmse: 26023
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos', 'name'), r2: -0.074, rmse: 35129
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'work_dir', 'name'), r2: 0.339, rmse: 27550
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos', 'work_dir'), r2: 0.421, rmse: 25787
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos', 'name'), r2: 0.333, rmse: 27675
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'work_dir', 'name'), r2: 0.278, rmse: 28800
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'work_dir', 'name'), r2: 0.270, rmse: 28962
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'qos'), r2: -0.983, rmse: 47733
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'work_dir'), r2: 0.436, rmse: 25450
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'name'), r2: -0.194, rmse: 37033
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos', 'work_dir'), r2: 0.365, rmse: 27006
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos', 'name'), r2: -0.047, rmse: 34679
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir', 'name'), r2: 0.396, rmse: 26337
# Encoding: label, Split time: 2022-01-01 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos', 'work_d
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'name'), r2: 0.070, rmse: 35266
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos'), r2: 0.145, rmse: 33817
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'work_dir'), r2: 0.630, rmse: 22241
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'name'), r2: 0.447, rmse: 27202
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'work_dir'), r2: 0.432, rmse: 27558
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'name'), r2: -0.224, rmse: 40454
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'work_dir', 'name'), r2: 0.586, rmse: 23529
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition'), r2: 0.354, rmse: 29379
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos'), r2: -0.078, rmse: 37966
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir'), r2: 0.631, rmse: 22212
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'name'), r2: 0.085, rmse: 34974
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos'), r2: 0.445, rmse: 27238
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'work_dir'), r2: 0.577, rmse: 23788
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'name'), r2: 0.536, rmse: 24898
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos', 'work_dir'), r2: 0.337, rmse: 29774
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos', 'name'), r2: -0.212, rmse: 40258
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'work_dir', 'name'), r2: 0.582, rmse: 23654
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'qos'), r2: 0.099, rmse: 34700
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'work_dir'), r2: 0.598, rmse: 23172
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'name'), r2: 0.295, rmse: 30710
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos', 'work_dir'), r2: 0.495, rmse: 25997
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos', 'name'), r2: -0.230, rmse: 40558
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'work_dir', 'name'), r2: 0.609, rmse: 22868
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos', 'work_dir'), r2: 0.587, rmse: 23497
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos', 'name'), r2: 0.497, rmse: 25933
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'work_dir', 'name'), r2: 0.578, rmse: 23749
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'qos', 'work_dir', 'name'), r2: 0.368, rmse: 29062
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'qos'), r2: 0.247, rmse: 31739
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'work_dir'), r2: 0.351, rmse: 29459
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'name'), r2: 0.421, rmse: 27821
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos', 'work_dir'), r2: 0.518, rmse: 25386
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos', 'name'), r2: -0.214, rmse: 40281
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir', 'name'), r2: 0.590, rmse: 23410
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos', 'work_dir'), r2: 0.579, rmse: 23730
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos', 'name'), r2: 0.442, rmse: 27326
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'work_dir', 'name'), r2: 0.607, rmse: 22919
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'qos', 'work_dir', 'name'), r2: 0.468, rmse: 26669
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'qos', 'work_dir'), r2: 0.543, rmse: 24715
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'qos', 'name'), r2: 0.459, rmse: 26894
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'work_dir', 'name'), r2: 0.544, rmse: 24678
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'qos', 'work_dir', 'name'), r2: 0.446, rmse: 27210
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'qos', 'work_dir', 'name'), r2: 0.508, rmse: 25637
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'qos', 'work_dir'), r2: 0.463, rmse: 26799
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'qos', 'name'), r2: 0.393, rmse: 28490
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'work_dir', 'name'), r2: 0.589, rmse: 23433
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'qos', 'work_dir', 'name'), r2: 0.554, rmse: 24410
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'partition', 'qos', 'work_dir', 'name'), r2: 0.526, rmse: 25183
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'account', 'partition', 'qos', 'work_dir', 'name'), r2: 0.567, rmse: 24072
# Encoding: target, Split time: 2022-01-07 00:00:00, features: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'partition', 'qos', 'work_dir', 'name'), r2: 0.539, rmse: 24820
# Optimal Features with target Encoding: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir')

# %%
print('Optimal Training Window:', optimal_training_window)
print('Optimal Testing Window:', optimal_testing_window)
print('Optimal Numerical Features:', optimal_numerical_features)
for encoding in ['label','onehot','target']:
    print(f'Optimal Features with {encoding} Encoding:', optimal_features[encoding])
# Out:
# Optimal Training Window: 60
# Optimal Testing Window: 11
# Optimal Numerical Features: ('wallclock_req', 'processors_req', 'gpus_req')
# Optimal Features with label Encoding: ('wallclock_req', 'processors_req', 'gpus_req', 'partition', 'name')
# Optimal Features with onehot Encoding: ('wallclock_req', 'processors_req', 'gpus_req', 'partition')
# Optimal Features with target Encoding: ('wallclock_req', 'processors_req', 'gpus_req', 'user', 'account', 'work_dir')
